# %%
import os
import re
os.getcwd()
# Out:
# '/Users/dleong/code/localfiles'

# %%
models_to_rerun=[]
except_regex_string=''
except_words = ['logging','packages','github','build','user','install','pip','START','OK']
except_regex_string = '|'.join(except_words)
prod_run_var_string = 'ENVIRONMENT=production AWS_PROFILE=production dbt run -m '

# %%
CWLogs = open('/Users/dleong/Downloads/log-events-viewer-result.csv', 'r')
CW_lines = CWLogs.readline()
dbt_logs_start = False
# print(CW_lines)
while CW_lines:
    CW_lines = CWLogs.readline()
    if re.search('Running with dbt',CW_lines):
        dbt_logs_start=True
    elif re.search('on-run-end hooks',CW_lines):
        dbt_logs_start=False
    if dbt_logs_start:
        model_name_re = re.search('[a-z\_]+\.{1}[a-z\_\d]+',CW_lines)
        if model_name_re:
            if not (re.search(except_regex_string,CW_lines)):
                model_name = model_name_re.group()
                # print(model_name)
                models_to_rerun.append(model_name)

CWLogs.close()

# %%
# USE WITH MULTILINE STRING
# CWLogs = open('/Users/dleong/Downloads/log-events-viewer-result.csv', 'r')
multiline_logs = """

16:18:09
16:18:09  Running 3 on-run-start hooks
16:18:09  1 of 3 START hook: logging.on-run-start.0 ...................................... [RUN]
16:18:09  1 of 3 OK hook: logging.on-run-start.0 ......................................... [OK in 0.00s]
16:18:15  2 of 3 START hook: logging.on-run-start.1 ...................................... [RUN]
16:18:15  2 of 3 OK hook: logging.on-run-start.1 ......................................... [OK in 0.00s]
16:18:15  3 of 3 START hook: logging.on-run-start.2 ...................................... [RUN]
16:18:15  3 of 3 OK hook: logging.on-run-start.2 ......................................... [COMMIT in 0.86s]
16:18:15
16:18:16  Concurrency: 8 threads (target='production')
16:18:16
16:18:16  1 of 404 START sql table model stg_gsheets.aca_hcc_dscrptn ..................... [RUN]
16:18:16  2 of 404 START sql table model stg_gsheets.aca_hcc_grp ......................... [RUN]
16:18:16  3 of 404 START sql table model stg_galileo_app.accounts ........................ [RUN]
16:18:16  4 of 404 START sql table model stg_galileo_app.accounts_address ................ [RUN]
16:18:16  5 of 404 START sql table model stg_galileo_app.accounts_insurance .............. [RUN]
16:18:16  6 of 404 START sql table model stg_galileo_app.accounts_pharmacies ............. [RUN]
16:18:16  7 of 404 START sql table model stg_galileo_app.address_delivery ................ [RUN]
16:18:16  8 of 404 START sql table model stg_gsheets.analytics_value_mappings ............ [RUN]
16:18:39  8 of 404 OK created sql table model stg_gsheets.analytics_value_mappings ....... [SELECT in 23.71s]
16:18:39  9 of 404 START sql table model stg_athena.athena_appointments .................. [RUN]
16:18:41  4 of 404 OK created sql table model stg_galileo_app.accounts_address ........... [SELECT in 25.74s]
16:18:41  10 of 404 START sql table model stg_gsheets.athena_claim_visit ................. [RUN]
16:18:43  7 of 404 OK created sql table model stg_galileo_app.address_delivery ........... [SELECT in 27.44s]
16:18:43  11 of 404 START sql table model stg_gsheets.athena_lab_results ................. [RUN]
16:18:45  1 of 404 OK created sql table model stg_gsheets.aca_hcc_dscrptn ................ [SELECT in 29.13s]
16:18:45  12 of 404 START sql table model stg_gsheets.athena_latest_vitals ............... [RUN]
16:18:46  2 of 404 OK created sql table model stg_gsheets.aca_hcc_grp .................... [SELECT in 30.73s]
16:18:46  13 of 404 START sql table model stg_galileo_app.auth_account_roles ............. [RUN]
16:18:48  3 of 404 OK created sql table model stg_galileo_app.accounts ................... [SELECT in 32.46s]
16:18:48  14 of 404 START sql view model file_ingestion_bcbsnc.bcbsnc_nuna_care_gaps ..... [RUN]
16:18:50  5 of 404 OK created sql table model stg_galileo_app.accounts_insurance ......... [SELECT in 34.39s]
16:18:50  15 of 404 START sql view model file_ingestion_bcbsnc.bcbsnc_risk_gaps .......... [RUN]
16:18:55  6 of 404 OK created sql table model stg_galileo_app.accounts_pharmacies ........ [SELECT in 39.29s]
16:18:55  16 of 404 START sql table model stg_bcnc.bcnc_mmr .............................. [RUN]
16:19:02  9 of 404 OK created sql table model stg_athena.athena_appointments ............. [SELECT in 22.23s]
16:19:02  17 of 404 START sql table model int_bcnc.bcnc_pqr_pcp .......................... [RUN]
16:19:03  12 of 404 OK created sql table model stg_gsheets.athena_latest_vitals .......... [SELECT in 18.61s]
16:19:03  18 of 404 START sql table model int_bcnc.bcnc_pqr_wrap ......................... [RUN]
16:19:07  11 of 404 OK created sql table model stg_gsheets.athena_lab_results ............ [SELECT in 24.21s]
16:19:07  19 of 404 START sql view model elation.bill .................................... [RUN]
16:19:09  10 of 404 OK created sql table model stg_gsheets.athena_claim_visit ............ [SELECT in 27.55s]
16:19:09  20 of 404 START sql view model elation.bill_item ............................... [RUN]
16:19:11  14 of 404 OK created sql view model file_ingestion_bcbsnc.bcbsnc_nuna_care_gaps  [CREATE VIEW in 22.48s]
16:19:11  21 of 404 START sql view model elation.bill_item_dx ............................ [RUN]
16:19:12  13 of 404 OK created sql table model stg_galileo_app.auth_account_roles ........ [SELECT in 25.97s]
16:19:12  22 of 404 START sql view model stg_lookup.bill_type_category ................... [RUN]
16:19:14  15 of 404 OK created sql view model file_ingestion_bcbsnc.bcbsnc_risk_gaps ..... [CREATE VIEW in 23.81s]
16:19:14  23 of 404 START sql table model stg_galileo_app.bulletins ...................... [RUN]
16:19:16  16 of 404 OK created sql table model stg_bcnc.bcnc_mmr ......................... [SELECT in 21.12s]
16:19:16  24 of 404 START sql view model stg_gsheets.care_plan_supplement ................ [RUN]
16:19:21  19 of 404 OK created sql view model elation.bill ............................... [CREATE VIEW in 13.88s]
16:19:21  25 of 404 START sql view model elation.caregaps ................................ [RUN]
16:19:25  18 of 404 OK created sql table model int_bcnc.bcnc_pqr_wrap .................... [SELECT in 21.13s]
16:19:25  26 of 404 START sql table model stg_galileo_app.careplan_templates ............. [RUN]
16:19:29  20 of 404 OK created sql view model elation.bill_item .......................... [CREATE VIEW in 19.67s]
16:19:29  27 of 404 START sql table model stg_galileo_app.careplans ...................... [RUN]
16:19:30  21 of 404 OK created sql view model elation.bill_item_dx ....................... [CREATE VIEW in 19.42s]
16:19:30  28 of 404 START sql table model stg_gsheets.case_mapping ....................... [RUN]
16:19:32  22 of 404 OK created sql view model stg_lookup.bill_type_category .............. [CREATE VIEW in 19.42s]
16:19:32  29 of 404 START sql table model stg_galileo_app.cases_tracking ................. [RUN]
16:19:39  17 of 404 OK created sql table model int_bcnc.bcnc_pqr_pcp ..................... [SELECT in 36.95s]
16:19:39  30 of 404 START sql view model stg_lookup.ccs_lookup ........................... [RUN]
16:19:40  23 of 404 OK created sql table model stg_galileo_app.bulletins ................. [SELECT in 26.61s]
16:19:40  31 of 404 START sql table model stg_galileo_app.census_2000_zip_county_state_mapping  [RUN]
16:19:43  24 of 404 OK created sql view model stg_gsheets.care_plan_supplement ........... [CREATE VIEW in 26.98s]
16:19:43  32 of 404 START sql table model stg_galileo_app.clinician_teams ................ [RUN]
16:19:45  25 of 404 OK created sql view model elation.caregaps ........................... [CREATE VIEW in 23.77s]
16:19:45  33 of 404 START sql table model stg_galileo_app.coupon_claims .................. [RUN]
16:19:49  26 of 404 OK created sql table model stg_galileo_app.careplan_templates ........ [SELECT in 24.29s]
16:19:49  34 of 404 START sql table model stg_galileo_app.coupons ........................ [RUN]
16:20:00  28 of 404 OK created sql table model stg_gsheets.case_mapping .................. [SELECT in 30.38s]
16:20:00  35 of 404 START sql table model stg_bcnc.csar .................................. [RUN]
16:20:02  30 of 404 OK created sql view model stg_lookup.ccs_lookup ...................... [CREATE VIEW in 23.92s]
16:20:02  36 of 404 START sql table model stg_galileo_app.customers ...................... [RUN]
16:20:05  27 of 404 OK created sql table model stg_galileo_app.careplans ................. [SELECT in 36.25s]
16:20:05  37 of 404 START sql table model int_galileo_app.date_day_spine ................. [RUN]
16:20:07  31 of 404 OK created sql table model stg_galileo_app.census_2000_zip_county_state_mapping  [SELECT in 26.43s]
16:20:07  38 of 404 START sql table model utilities.date_month_spine__long ............... [RUN]
16:20:08  32 of 404 OK created sql table model stg_galileo_app.clinician_teams ........... [SELECT in 25.20s]
16:20:08  39 of 404 START sql table model utilities.date_spine_month ..................... [RUN]
16:20:21  33 of 404 OK created sql table model stg_galileo_app.coupon_claims ............. [SELECT in 35.42s]
16:20:21  40 of 404 START sql table model stg_galileo_app.delivery_contracts ............. [RUN]
16:20:24  34 of 404 OK created sql table model stg_galileo_app.coupons ................... [SELECT in 34.99s]
16:20:24  41 of 404 START sql table model stg_galileo_app.delivery_patient_account_mappings  [RUN]
16:20:31  29 of 404 OK created sql table model stg_galileo_app.cases_tracking ............ [SELECT in 59.54s]
16:20:31  42 of 404 START sql table model stg_galileo_app.delivery_payers ................ [RUN]
16:20:36  35 of 404 OK created sql table model stg_bcnc.csar ............................. [SELECT in 35.57s]
16:20:36  43 of 404 START sql table model stg_galileo_app.delivery_phone_numbers ......... [RUN]
16:20:41  40 of 404 OK created sql table model stg_galileo_app.delivery_contracts ........ [SELECT in 20.40s]
16:20:41  44 of 404 START sql table model stg_galileo_app.delivery_team_assignments ...... [RUN]
16:20:43  41 of 404 OK created sql table model stg_galileo_app.delivery_patient_account_mappings  [SELECT in 19.12s]
16:20:43  45 of 404 START sql table model stg_galileo_app.delivery_teams ................. [RUN]
16:20:45  39 of 404 OK created sql table model utilities.date_spine_month ................ [SELECT in 36.34s]
16:20:45  46 of 404 START sql table model stg_galileo_app.doctors ........................ [RUN]
16:20:46  36 of 404 OK created sql table model stg_galileo_app.customers ................. [SELECT in 43.15s]
16:20:46  47 of 404 START sql view model elation.document_tag ............................ [RUN]
16:20:48  37 of 404 OK created sql table model int_galileo_app.date_day_spine ............ [SELECT in 42.68s]
16:20:48  48 of 404 START sql view model stg_lookup.drg .................................. [RUN]
16:20:51  42 of 404 OK created sql table model stg_galileo_app.delivery_payers ........... [SELECT in 19.27s]
16:20:51  49 of 404 START sql table model stg_galileo_app.eligibility_failures ........... [RUN]
16:20:52  38 of 404 OK created sql table model utilities.date_month_spine__long .......... [SELECT in 44.82s]
16:20:52  50 of 404 START sql table model stg_first_databank.fdb_etc ..................... [RUN]
16:21:01  43 of 404 OK created sql table model stg_galileo_app.delivery_phone_numbers .... [SELECT in 24.69s]
16:21:01  51 of 404 START sql table model stg_first_databank.fdb_etc_gcnseqno ............ [RUN]
16:21:03  44 of 404 OK created sql table model stg_galileo_app.delivery_team_assignments . [SELECT in 21.97s]
16:21:03  52 of 404 START sql table model stg_first_databank.fdb_etc_medid ............... [RUN]
16:21:06  45 of 404 OK created sql table model stg_galileo_app.delivery_teams ............ [SELECT in 22.83s]
16:21:06  53 of 404 START sql table model stg_first_databank.fdb_etc_ndc ................. [RUN]
16:21:07  47 of 404 OK created sql view model elation.document_tag ....................... [CREATE VIEW in 21.77s]
16:21:07  54 of 404 START sql table model stg_first_databank.fdb_gcnseqno ................ [RUN]
16:21:10  46 of 404 OK created sql table model stg_galileo_app.doctors ................... [SELECT in 25.16s]
16:21:10  55 of 404 START sql table model stg_first_databank.fdb_hiclseqno ............... [RUN]
16:21:12  48 of 404 OK created sql view model stg_lookup.drg ............................. [CREATE VIEW in 24.84s]
16:21:12  56 of 404 START sql table model stg_first_databank.fdb_medid ................... [RUN]
16:21:14  49 of 404 OK created sql table model stg_galileo_app.eligibility_failures ...... [SELECT in 23.40s]
16:21:14  57 of 404 START sql table model stg_first_databank.fdb_ndc ..................... [RUN]
16:21:16  50 of 404 OK created sql table model stg_first_databank.fdb_etc ................ [SELECT in 23.94s]
16:21:16  58 of 404 START sql table model stg_first_databank.fdb_ndc_medid ............... [RUN]
16:21:23  51 of 404 OK created sql table model stg_first_databank.fdb_etc_gcnseqno ....... [SELECT in 22.07s]
16:21:23  59 of 404 START sql table model stg_galileo_app.feedbacks ...................... [RUN]
16:21:25  52 of 404 OK created sql table model stg_first_databank.fdb_etc_medid .......... [SELECT in 21.84s]
16:21:25  60 of 404 START sql table model stg_galileo_app.follow_up_templates ............ [RUN]
16:21:30  53 of 404 OK created sql table model stg_first_databank.fdb_etc_ndc ............ [SELECT in 24.61s]
16:21:30  61 of 404 START sql table model stg_galileo_app.follow_ups ..................... [RUN]
16:21:34  55 of 404 OK created sql table model stg_first_databank.fdb_hiclseqno .......... [SELECT in 24.37s]
16:21:34  62 of 404 START sql table model stg_gchart.gchart_care_documentation ........... [RUN]
16:21:37  54 of 404 OK created sql table model stg_first_databank.fdb_gcnseqno ........... [SELECT in 28.84s]
16:21:37  63 of 404 START sql table model stg_galileo_app.group_eligibility_claims ....... [RUN]
16:21:39  56 of 404 OK created sql table model stg_first_databank.fdb_medid .............. [SELECT in 26.27s]
16:21:39  64 of 404 START sql table model stg_galileo_app.group_eligibility_tokens ....... [RUN]
16:21:41  57 of 404 OK created sql table model stg_first_databank.fdb_ndc ................ [SELECT in 27.01s]
16:21:41  65 of 404 START sql table model stg_galileo_app.groups ......................... [RUN]
16:21:44  58 of 404 OK created sql table model stg_first_databank.fdb_ndc_medid .......... [SELECT in 28.02s]
16:21:44  66 of 404 START sql table model stg_health_gorilla.health_gorilla_encounters ... [RUN]
16:21:46  59 of 404 OK created sql table model stg_galileo_app.feedbacks ................. [SELECT in 22.86s]
16:21:46  67 of 404 START sql table model stg_health_gorilla.health_gorilla_procedures ... [RUN]
16:21:48  60 of 404 OK created sql table model stg_galileo_app.follow_up_templates ....... [SELECT in 23.23s]
16:21:48  68 of 404 START sql view model stg_healthix.healthix_adt_alerts ................ [RUN]
16:21:50  61 of 404 OK created sql table model stg_galileo_app.follow_ups ................ [SELECT in 19.91s]
16:21:50  69 of 404 START sql table model int_delivery.hedis_bcs_gchart_prevention_closed  [RUN]
16:22:04  64 of 404 OK created sql table model stg_galileo_app.group_eligibility_tokens .. [SELECT in 25.10s]
16:22:04  70 of 404 START sql table model int_delivery.hedis_cbp_gchart_active_issues .... [RUN]
16:22:06  65 of 404 OK created sql table model stg_galileo_app.groups .................... [SELECT in 24.56s]
16:22:06  71 of 404 START sql table model int_delivery.hedis_cerv_gchart_prevention_closed  [RUN]
16:22:09  68 of 404 OK created sql view model stg_healthix.healthix_adt_alerts ........... [CREATE VIEW in 20.62s]
16:22:09  72 of 404 START sql table model int_delivery.hedis_chl_gchart_prevention ....... [RUN]
16:22:15  66 of 404 OK created sql table model stg_health_gorilla.health_gorilla_encounters  [SELECT in 31.20s]
16:22:15  73 of 404 START sql table model int_delivery.hedis_col_gchart_prevention_closed  [RUN]
16:22:17  69 of 404 OK created sql table model int_delivery.hedis_bcs_gchart_prevention_closed  [SELECT in 26.41s]
16:22:17  74 of 404 START sql table model int_delivery.hedis_eye_gchart_prevention_closed  [RUN]
16:22:19  67 of 404 OK created sql table model stg_health_gorilla.health_gorilla_procedures  [SELECT in 33.87s]
16:22:20  75 of 404 START sql table model int_delivery.hedis_hba1c_gchart_active_issues_closed  [RUN]
16:22:22  63 of 404 OK created sql table model stg_galileo_app.group_eligibility_claims .. [SELECT in 45.09s]
16:22:22  76 of 404 START sql table model int_delivery.hedis_hba1c_gchart_prevention_closed  [RUN]
16:22:23  70 of 404 OK created sql table model int_delivery.hedis_cbp_gchart_active_issues  [SELECT in 19.64s]
16:22:23  77 of 404 START sql table model int_delivery.hedis_medrec_gformtoc ............. [RUN]
16:22:25  71 of 404 OK created sql table model int_delivery.hedis_cerv_gchart_prevention_closed  [SELECT in 19.91s]
16:22:25  78 of 404 START sql table model int_delivery.hedis_mrp_manual_2020 ............. [RUN]
16:22:28  72 of 404 OK created sql table model int_delivery.hedis_chl_gchart_prevention .. [SELECT in 19.00s]
16:22:28  79 of 404 START sql table model int_delivery.hedis_neph_gchart_prevention_closed  [RUN]
16:22:39  74 of 404 OK created sql table model int_delivery.hedis_eye_gchart_prevention_closed  [SELECT in 21.90s]
16:22:39  80 of 404 START sql view model file_ingestion_uhc.hf_prior_day_admissions_ingestion  [RUN]
16:22:42  73 of 404 OK created sql table model int_delivery.hedis_col_gchart_prevention_closed  [SELECT in 27.42s]
16:22:42  81 of 404 START sql table model stg_healthfirst.hf_roster_alt .................. [RUN]
16:22:44  77 of 404 OK created sql table model int_delivery.hedis_medrec_gformtoc ........ [SELECT in 20.93s]
16:22:44  82 of 404 START sql table model stg_gsheets.hf_rtc_wc_manual_visits ............ [RUN]
16:22:48  78 of 404 OK created sql table model int_delivery.hedis_mrp_manual_2020 ........ [SELECT in 22.90s]
16:22:48  83 of 404 START sql table model int_delivery.hg_lab_results_deduplicated ....... [RUN]
16:22:50  79 of 404 OK created sql table model int_delivery.hedis_neph_gchart_prevention_closed  [SELECT in 22.44s]
16:22:50  84 of 404 START sql table model stg_stripe.invoice ............................. [RUN]
16:22:52  75 of 404 OK created sql table model int_delivery.hedis_hba1c_gchart_active_issues_closed  [SELECT in 32.26s]
16:22:52  85 of 404 START sql table model stg_stripe.invoice_line_item ................... [RUN]
16:22:57  76 of 404 OK created sql table model int_delivery.hedis_hba1c_gchart_prevention_closed  [SELECT in 35.07s]
16:22:57  86 of 404 START sql view model elation.lab_result .............................. [RUN]
16:23:00  80 of 404 OK created sql view model file_ingestion_uhc.hf_prior_day_admissions_ingestion  [CREATE VIEW in 21.61s]
16:23:00  87 of 404 START sql table model stg_galileo_app.medicare_medicaid_enrollment ... [RUN]
16:23:09  82 of 404 OK created sql table model stg_gsheets.hf_rtc_wc_manual_visits ....... [SELECT in 24.49s]
16:23:09  88 of 404 START sql table model stg_galileo_app.messages ....................... [RUN]
16:23:11  81 of 404 OK created sql table model stg_healthfirst.hf_roster_alt ............. [SELECT in 28.84s]
16:23:11  89 of 404 START sql incremental model stg_mixpanel.mobile_website_event ........ [RUN]
16:23:13  86 of 404 OK created sql view model elation.lab_result ......................... [CREATE VIEW in 16.28s]
16:23:13  90 of 404 START sql table model stg_galileo_app.outreaches ..................... [RUN]
16:23:18  84 of 404 OK created sql table model stg_stripe.invoice ........................ [SELECT in 27.72s]
16:23:18  91 of 404 START sql view model elation.patient ................................. [RUN]
16:23:21  85 of 404 OK created sql table model stg_stripe.invoice_line_item .............. [SELECT in 29.19s]
16:23:21  92 of 404 START sql view model elation.patient_tag ............................. [RUN]
16:23:26  87 of 404 OK created sql table model stg_galileo_app.medicare_medicaid_enrollment  [SELECT in 25.16s]
16:23:26  93 of 404 START sql table model stg_galileo_app.phr_allergies .................. [RUN]
16:23:38  91 of 404 OK created sql view model elation.patient ............................ [CREATE VIEW in 19.96s]
16:23:38  94 of 404 START sql table model stg_galileo_app.phr_allergies_tracking ......... [RUN]
16:23:40  83 of 404 OK created sql table model int_delivery.hg_lab_results_deduplicated .. [SELECT in 51.23s]
16:23:40  95 of 404 START sql table model stg_galileo_app.phr_issues ..................... [RUN]
16:23:42  90 of 404 OK created sql table model stg_galileo_app.outreaches ................ [SELECT in 28.57s]
16:23:42  96 of 404 START sql table model stg_galileo_app.phr_issues_tracking ............ [RUN]
16:23:44  92 of 404 OK created sql view model elation.patient_tag ........................ [CREATE VIEW in 22.67s]
16:23:44  97 of 404 START sql table model stg_galileo_app.phr_medications ................ [RUN]
16:23:46  93 of 404 OK created sql table model stg_galileo_app.phr_allergies ............. [SELECT in 20.21s]
16:23:46  98 of 404 START sql table model stg_galileo_app.phr_medications_tracking ....... [RUN]
16:23:57  94 of 404 OK created sql table model stg_galileo_app.phr_allergies_tracking .... [SELECT in 18.94s]
16:23:57  99 of 404 START sql table model stg_galileo_app.phr_procedures ................. [RUN]
16:24:05  95 of 404 OK created sql table model stg_galileo_app.phr_issues ................ [SELECT in 25.79s]
16:24:05  100 of 404 START sql table model stg_galileo_app.phr_procedures_tracking ....... [RUN]
16:24:12  96 of 404 OK created sql table model stg_galileo_app.phr_issues_tracking ....... [SELECT in 30.23s]
16:24:12  101 of 404 START sql table model stg_galileo_app.phr_vaccines .................. [RUN]
16:24:14  98 of 404 OK created sql table model stg_galileo_app.phr_medications_tracking .. [SELECT in 28.42s]
16:24:14  102 of 404 START sql table model stg_galileo_app.phr_vaccines_tracking ......... [RUN]
16:24:16  97 of 404 OK created sql table model stg_galileo_app.phr_medications ........... [SELECT in 32.54s]
16:24:16  103 of 404 START sql view model stg_lookup.place_of_service .................... [RUN]
16:24:20  99 of 404 OK created sql table model stg_galileo_app.phr_procedures ............ [SELECT in 23.54s]
16:24:20  104 of 404 START sql table model stg_stripe.plan ............................... [RUN]
16:24:34  100 of 404 OK created sql table model stg_galileo_app.phr_procedures_tracking .. [SELECT in 28.57s]
16:24:34  105 of 404 START sql table model stg_galileo_app.preferred_providers ........... [RUN]
16:24:37  103 of 404 OK created sql view model stg_lookup.place_of_service ............... [CREATE VIEW in 20.48s]
16:24:37  106 of 404 START sql table model stg_galileo_app.preferred_providers_tracking .. [RUN]
16:24:39  101 of 404 OK created sql table model stg_galileo_app.phr_vaccines ............. [SELECT in 27.29s]
16:24:39  107 of 404 START sql table model stg_galileo_app.primary_care_providers ........ [RUN]
16:24:41  102 of 404 OK created sql table model stg_galileo_app.phr_vaccines_tracking .... [SELECT in 27.03s]
16:24:41  108 of 404 START sql view model stg_lookup.procedure_category .................. [RUN]
16:24:45  104 of 404 OK created sql table model stg_stripe.plan .......................... [SELECT in 24.89s]
16:24:45  109 of 404 START sql view model stg_lookup.procedure_spikes .................... [RUN]
16:24:55  89 of 404 OK created sql incremental model stg_mixpanel.mobile_website_event ... [INSERT 0 5 in 103.54s]
16:24:55  110 of 404 START sql view model stg_lookup.procedures_desc ..................... [RUN]
16:24:55  106 of 404 OK created sql table model stg_galileo_app.preferred_providers_tracking  [SELECT in 18.13s]
16:24:55  111 of 404 START sql table model stg_galileo_app.provider_accounts ............. [RUN]
16:24:56  105 of 404 OK created sql table model stg_galileo_app.preferred_providers ...... [SELECT in 22.49s]
16:24:56  112 of 404 START sql table model stg_gsheets.quality_deal_metadata_raw ......... [RUN]
16:24:59  107 of 404 OK created sql table model stg_galileo_app.primary_care_providers ... [SELECT in 19.67s]
16:24:59  113 of 404 START sql incremental model stg_redshift.query_history .............. [RUN]
16:25:05  108 of 404 OK created sql view model stg_lookup.procedure_category ............. [CREATE VIEW in 23.57s]
16:25:05  114 of 404 START sql table model stg_galileo_app.quest_order ................... [RUN]
16:25:08  109 of 404 OK created sql view model stg_lookup.procedure_spikes ............... [CREATE VIEW in 22.34s]
16:25:08  115 of 404 START sql table model stg_galileo_app.quest_results ................. [RUN]
16:25:11  110 of 404 OK created sql view model stg_lookup.procedures_desc ................ [CREATE VIEW in 16.27s]
16:25:11  116 of 404 START sql table model stg_galileo_app.quiz_attempts ................. [RUN]
16:25:15  62 of 404 OK created sql table model stg_gchart.gchart_care_documentation ...... [SELECT in 221.01s]
16:25:15  117 of 404 START sql table model stg_galileo_app.quiz_categories ............... [RUN]
16:25:19  112 of 404 OK created sql table model stg_gsheets.quality_deal_metadata_raw .... [SELECT in 23.00s]
16:25:19  118 of 404 START sql table model stg_galileo_app.quiz_templates ................ [RUN]
16:25:24  111 of 404 OK created sql table model stg_galileo_app.provider_accounts ........ [SELECT in 29.45s]
16:25:24  119 of 404 START sql view model stg_galileo_app.raw_case_notations ............. [RUN]
16:25:32  116 of 404 OK created sql table model stg_galileo_app.quiz_attempts ............ [SELECT in 21.11s]
16:25:32  120 of 404 START sql table model stg_galileo_app.raw_cases ..................... [RUN]
16:25:34  114 of 404 OK created sql table model stg_galileo_app.quest_order .............. [SELECT in 29.59s]
16:25:34  121 of 404 START sql table model stg_galileo_app.raw_delivery_patients ......... [RUN]
16:25:36  117 of 404 OK created sql table model stg_galileo_app.quiz_categories .......... [SELECT in 20.92s]
16:25:36  122 of 404 START sql table model stg_galileo_app.raw_todo_operator_states ...... [RUN]
16:25:38  113 of 404 OK created sql incremental model stg_redshift.query_history ......... [INSERT 0 13486 in 38.96s]
16:25:38  115 of 404 OK created sql table model stg_galileo_app.quest_results ............ [SELECT in 30.28s]
16:25:38  123 of 404 START sql table model stg_galileo_app.raw_todos ..................... [RUN]
16:25:38  124 of 404 START sql view model elation.report ................................. [RUN]
16:25:40  118 of 404 OK created sql table model stg_galileo_app.quiz_templates ........... [SELECT in 20.16s]
16:25:40  125 of 404 START sql view model stg_lookup.revenue_code ........................ [RUN]
16:25:41  119 of 404 OK created sql view model stg_galileo_app.raw_case_notations ........ [CREATE VIEW in 16.75s]
16:25:41  126 of 404 START sql table model stg_salesforce_enterprise.salesforce_enterprise_accounts  [RUN]
16:25:51  120 of 404 OK created sql table model stg_galileo_app.raw_cases ................ [SELECT in 19.22s]
16:25:51  127 of 404 START sql view model stg_salesforce_enterprise.salesforce_enterprise_contact  [RUN]
16:25:53  121 of 404 OK created sql table model stg_galileo_app.raw_delivery_patients .... [SELECT in 18.45s]
16:25:53  128 of 404 START sql view model elation.service_location ....................... [RUN]
16:25:57  124 of 404 OK created sql view model elation.report ............................ [CREATE VIEW in 18.61s]
16:25:57  129 of 404 START sql table model stg_servicetitan.servicetitan_med_claims_anthem  [RUN]
16:25:59  125 of 404 OK created sql view model stg_lookup.revenue_code ................... [CREATE VIEW in 19.27s]
16:25:59  130 of 404 START sql table model stg_servicetitan.servicetitan_med_claims_cigna  [RUN]
16:26:03  126 of 404 OK created sql table model stg_salesforce_enterprise.salesforce_enterprise_accounts  [SELECT in 21.66s]
16:26:03  131 of 404 START sql table model stg_servicetitan.servicetitan_members_cigna ... [RUN]
16:26:10  127 of 404 OK created sql view model stg_salesforce_enterprise.salesforce_enterprise_contact  [CREATE VIEW in 18.24s]
16:26:10  132 of 404 START sql table model stg_galileo_app.shifts ........................ [RUN]
16:26:19  128 of 404 OK created sql view model elation.service_location .................. [CREATE VIEW in 25.89s]
16:26:19  133 of 404 START sql table model stg_galileo_app.sponsor_mapping ............... [RUN]
16:26:23  123 of 404 OK created sql table model stg_galileo_app.raw_todos ................ [SELECT in 44.64s]
16:26:23  134 of 404 START sql view model stg_braze.stg_braze_subscription_event ......... [RUN]
16:26:27  129 of 404 OK created sql table model stg_servicetitan.servicetitan_med_claims_anthem  [SELECT in 30.88s]
16:26:27  135 of 404 START sql table model stg_stripe.subscription ....................... [RUN]
16:26:30  130 of 404 OK created sql table model stg_servicetitan.servicetitan_med_claims_cigna  [SELECT in 31.27s]
16:26:30  136 of 404 START sql table model stg_galileo_app.subscription_periods .......... [RUN]
16:26:35  131 of 404 OK created sql table model stg_servicetitan.servicetitan_members_cigna  [SELECT in 32.04s]
16:26:35  137 of 404 START sql table model stg_galileo_app.surescripts_erx ............... [RUN]
16:26:41  132 of 404 OK created sql table model stg_galileo_app.shifts ................... [SELECT in 31.73s]
16:26:41  138 of 404 START sql table model stg_galileo_app.surescripts_refill_request .... [RUN]
16:26:44  133 of 404 OK created sql table model stg_galileo_app.sponsor_mapping .......... [SELECT in 25.51s]
16:26:44  139 of 404 START sql table model stg_galileo_app.surescripts_refill_response ... [RUN]
16:26:46  88 of 404 OK created sql table model stg_galileo_app.messages .................. [SELECT in 217.31s]
16:26:46  140 of 404 START sql table model stg_galileo_app.surescripts_refill_response_transactions  [RUN]
16:26:48  134 of 404 OK created sql view model stg_braze.stg_braze_subscription_event .... [CREATE VIEW in 25.31s]
16:26:48  141 of 404 START sql view model file_ingestion_uhc.uhc_claims .................. [RUN]
16:26:52  136 of 404 OK created sql table model stg_galileo_app.subscription_periods ..... [SELECT in 22.18s]
16:26:52  142 of 404 START sql view model stg_uhc.uhc_claims_v1 .......................... [RUN]
16:26:56  135 of 404 OK created sql table model stg_stripe.subscription .................. [SELECT in 28.97s]
16:26:56  143 of 404 START sql view model file_ingestion_uhc.uhc_emergency_room_volume_report  [RUN]
16:27:07  137 of 404 OK created sql table model stg_galileo_app.surescripts_erx .......... [SELECT in 31.90s]
16:27:07  144 of 404 START sql view model file_ingestion_uhc.uhc_ifp_emergency_room_report  [RUN]
16:27:15  138 of 404 OK created sql table model stg_galileo_app.surescripts_refill_request  [SELECT in 34.15s]
16:27:15  145 of 404 START sql view model file_ingestion_uhc.uhc_ifp_inpatient_report .... [RUN]
16:27:18  141 of 404 OK created sql view model file_ingestion_uhc.uhc_claims ............. [CREATE VIEW in 29.80s]
16:27:18  146 of 404 START sql view model file_ingestion_uhc.uhc_inpatient_volume_report . [RUN]
16:27:20  139 of 404 OK created sql table model stg_galileo_app.surescripts_refill_response  [SELECT in 35.85s]
16:27:20  147 of 404 START sql table model stg_uhc.uhc_members_834 ....................... [RUN]
16:27:22  140 of 404 OK created sql table model stg_galileo_app.surescripts_refill_response_transactions  [SELECT in 36.11s]
16:27:22  148 of 404 START sql table model stg_gsheets.uhc_ra_closed_suspects_members .... [RUN]
16:27:24  142 of 404 OK created sql view model stg_uhc.uhc_claims_v1 ..................... [CREATE VIEW in 32.01s]
16:27:24  149 of 404 START sql view model file_ingestion_uhc.uhc_risk_score .............. [RUN]
16:27:27  122 of 404 OK created sql table model stg_galileo_app.raw_todo_operator_states . [SELECT in 111.22s]
16:27:27  150 of 404 START sql table model stg_villagecare.vcm_claims .................... [RUN]
16:27:29  143 of 404 OK created sql view model file_ingestion_uhc.uhc_emergency_room_volume_report  [CREATE VIEW in 32.97s]
16:27:29  151 of 404 START sql table model stg_villagecare.vcm_roster .................... [RUN]
16:27:31  144 of 404 OK created sql view model file_ingestion_uhc.uhc_ifp_emergency_room_report  [CREATE VIEW in 24.61s]
16:27:31  152 of 404 START sql view model elation.visit_note ............................. [RUN]
16:27:33  145 of 404 OK created sql view model file_ingestion_uhc.uhc_ifp_inpatient_report  [CREATE VIEW in 17.47s]
16:27:33  153 of 404 START sql view model elation.visit_note_document_tag ................ [RUN]
16:27:36  146 of 404 OK created sql view model file_ingestion_uhc.uhc_inpatient_volume_report  [CREATE VIEW in 18.17s]
16:27:36  154 of 404 START sql view model elation.vital_bp ............................... [RUN]
16:27:42  148 of 404 OK created sql table model stg_gsheets.uhc_ra_closed_suspects_members  [SELECT in 19.29s]
16:27:42  155 of 404 START sql view model file_ingestion_wellcare.wellcare_census ........ [RUN]
16:27:45  149 of 404 OK created sql view model file_ingestion_uhc.uhc_risk_score ......... [CREATE VIEW in 20.86s]
16:27:45  156 of 404 START sql view model file_ingestion_wellcare.wellcare_claims ........ [RUN]
16:27:52  150 of 404 OK created sql table model stg_villagecare.vcm_claims ............... [SELECT in 24.42s]
16:27:52  157 of 404 START sql view model file_ingestion_wellcare.wellcare_rosters ....... [RUN]
16:27:54  152 of 404 OK created sql view model elation.visit_note ........................ [CREATE VIEW in 22.58s]
16:27:54  158 of 404 START sql table model stg_galileo_app.zoom_video_consultations ...... [RUN]
16:27:56  151 of 404 OK created sql table model stg_villagecare.vcm_roster ............... [SELECT in 27.06s]
16:27:56  159 of 404 START sql table model stg_galileo_app.delivery_insurances ........... [RUN]
16:27:58  153 of 404 OK created sql view model elation.visit_note_document_tag ........... [CREATE VIEW in 24.86s]
16:27:58  160 of 404 START sql table model stg_risk_adjustment.uhc_suspected_hcc ......... [RUN]
16:28:00  154 of 404 OK created sql view model elation.vital_bp .......................... [CREATE VIEW in 23.85s]
16:28:00  161 of 404 START sql table model int_galileo_app.priority_address .............. [RUN]
16:28:02  155 of 404 OK created sql view model file_ingestion_wellcare.wellcare_census ... [CREATE VIEW in 19.95s]
16:28:02  162 of 404 START sql table model int_galileo_app.active_primary_address ........ [RUN]
16:28:03  156 of 404 OK created sql view model file_ingestion_wellcare.wellcare_claims ... [CREATE VIEW in 18.03s]
16:28:03  163 of 404 START sql table model int_galileo_app.accounts_insurance_daily ...... [RUN]
16:28:09  157 of 404 OK created sql view model file_ingestion_wellcare.wellcare_rosters .. [CREATE VIEW in 16.87s]
16:28:09  164 of 404 START sql table model int_galileo_app.accounts_pharmacies_daily ..... [RUN]
16:28:15  158 of 404 OK created sql table model stg_galileo_app.zoom_video_consultations . [SELECT in 20.86s]
16:28:15  165 of 404 START sql table model int_bcnc.bcnc_pqr_wrap_and_pcp ................ [RUN]
16:28:17  159 of 404 OK created sql table model stg_galileo_app.delivery_insurances ...... [SELECT in 20.60s]
16:28:17  166 of 404 START sql table model int_risk_adjustment.mra_person_prep ........... [RUN]
16:28:19  161 of 404 OK created sql table model int_galileo_app.priority_address ......... [SELECT in 19.08s]
16:28:19  167 of 404 START sql table model int_bcnc.bcnc_pqr_deduplicate ................. [RUN]
16:28:22  162 of 404 OK created sql table model int_galileo_app.active_primary_address ... [SELECT in 20.94s]
16:28:22  168 of 404 START sql table model int_galileo_app.bulletins_actioned ............ [RUN]
16:28:24  163 of 404 OK created sql table model int_galileo_app.accounts_insurance_daily . [SELECT in 20.86s]
16:28:24  169 of 404 START sql table model marts_digital.case_careplans .................. [RUN]
16:28:28  160 of 404 OK created sql table model stg_risk_adjustment.uhc_suspected_hcc .... [SELECT in 30.07s]
16:28:28  170 of 404 START sql table model int_galileo_app.referrals_by_friend ........... [RUN]
16:28:30  164 of 404 OK created sql table model int_galileo_app.accounts_pharmacies_daily  [SELECT in 21.83s]
16:28:30  171 of 404 START sql table model int_galileo_app.active_phone_numbers .......... [RUN]
16:28:35  166 of 404 OK created sql table model int_risk_adjustment.mra_person_prep ...... [SELECT in 17.99s]
16:28:35  172 of 404 START sql table model int_lookup.etc ................................ [RUN]
16:28:44  167 of 404 OK created sql table model int_bcnc.bcnc_pqr_deduplicate ............ [SELECT in 25.06s]
16:28:44  173 of 404 START sql table model int_galileo_app.feedbacks_daily ............... [RUN]
16:28:48  168 of 404 OK created sql table model int_galileo_app.bulletins_actioned ....... [SELECT in 25.53s]
16:28:48  174 of 404 START sql table model marts_digital.case_follow_ups ................. [RUN]
16:28:53  147 of 404 OK created sql table model stg_uhc.uhc_members_834 .................. [SELECT in 92.88s]
16:28:53  175 of 404 START sql table model int_galileo_app.eligibility_tokens_most_recent  [RUN]
16:28:55  170 of 404 OK created sql table model int_galileo_app.referrals_by_friend ...... [SELECT in 26.42s]
16:28:55  176 of 404 START sql table model stg_lookup.affiliation_lookup_union ........... [RUN]
16:28:56  171 of 404 OK created sql table model int_galileo_app.active_phone_numbers ..... [SELECT in 25.79s]
16:28:56  177 of 404 START sql table model int_partners.dte_roster_details ............... [RUN]
16:28:59  169 of 404 OK created sql table model marts_digital.case_careplans ............. [SELECT in 35.37s]
16:28:59  178 of 404 START sql table model stg_mvp.mvp_full_roster ....................... [RUN]
16:29:02  165 of 404 OK created sql table model int_bcnc.bcnc_pqr_wrap_and_pcp ........... [SELECT in 47.06s]
16:29:02  179 of 404 START sql table model stg_mvp.mvp_roster ............................ [RUN]
16:29:04  173 of 404 OK created sql table model int_galileo_app.feedbacks_daily .......... [SELECT in 20.02s]
16:29:04  180 of 404 START sql table model int_delivery.hedis_bcs_hg_closed .............. [RUN]
16:29:11  172 of 404 OK created sql table model int_lookup.etc ........................... [SELECT in 35.48s]
16:29:11  181 of 404 START sql table model int_delivery.hedis_ccs_hg_prc_cyto_prevention . [RUN]
16:29:15  174 of 404 OK created sql table model marts_digital.case_follow_ups ............ [SELECT in 27.32s]
16:29:15  182 of 404 START sql table model int_delivery.hedis_ccs_hg_prc_hrpv_prevention . [RUN]
16:29:21  175 of 404 OK created sql table model int_galileo_app.eligibility_tokens_most_recent  [SELECT in 27.41s]
16:29:21  183 of 404 START sql table model int_delivery.hedis_col_hg_closed .............. [RUN]
16:29:22  176 of 404 OK created sql table model stg_lookup.affiliation_lookup_union ...... [SELECT in 27.58s]
16:29:22  184 of 404 START sql table model int_delivery.hedis_ccs_hg_lab_cytology_prevention  [RUN]
16:29:24  177 of 404 OK created sql table model int_partners.dte_roster_details .......... [SELECT in 27.55s]
16:29:24  185 of 404 START sql table model int_delivery.hedis_ccs_hg_lab_hrpv_prevention . [RUN]
16:29:27  180 of 404 OK created sql table model int_delivery.hedis_bcs_hg_closed ......... [SELECT in 23.07s]
16:29:27  186 of 404 START sql table model int_delivery.hedis_col_hg_loinc_closed ........ [RUN]
16:29:29  179 of 404 OK created sql table model stg_mvp.mvp_roster ....................... [SELECT in 27.51s]
16:29:29  187 of 404 START sql table model int_delivery.hedis_hba1c_hg_closed ............ [RUN]
16:29:34  181 of 404 OK created sql table model int_delivery.hedis_ccs_hg_prc_cyto_prevention  [SELECT in 23.51s]
16:29:34  188 of 404 START sql table model int_delivery.hedis_neph_hg_closed ............. [RUN]
16:29:36  182 of 404 OK created sql table model int_delivery.hedis_ccs_hg_prc_hrpv_prevention  [SELECT in 20.77s]
16:29:36  189 of 404 START sql table model int_galileo_app.patient_outreach_summary ...... [RUN]
16:29:40  185 of 404 OK created sql table model int_delivery.hedis_ccs_hg_lab_hrpv_prevention  [SELECT in 16.42s]
16:29:40  190 of 404 START sql table model int_galileo_app.phr_allergies_daily ........... [RUN]
16:29:42  183 of 404 OK created sql table model int_delivery.hedis_col_hg_closed ......... [SELECT in 21.01s]
16:29:42  191 of 404 START sql table model int_galileo_app.phr_issues_daily .............. [RUN]
16:29:43  184 of 404 OK created sql table model int_delivery.hedis_ccs_hg_lab_cytology_prevention  [SELECT in 21.27s]
16:29:43  192 of 404 START sql table model int_galileo_app.phr_medications_daily ......... [RUN]
16:29:51  186 of 404 OK created sql table model int_delivery.hedis_col_hg_loinc_closed ... [SELECT in 23.57s]
16:29:51  193 of 404 START sql table model int_galileo_app.phr_procedures_daily .......... [RUN]
16:29:57  188 of 404 OK created sql table model int_delivery.hedis_neph_hg_closed ........ [SELECT in 22.56s]
16:29:57  194 of 404 START sql table model int_galileo_app.phr_vaccines_daily ............ [RUN]
16:29:59  187 of 404 OK created sql table model int_delivery.hedis_hba1c_hg_closed ....... [SELECT in 29.61s]
16:29:59  195 of 404 START sql view model int_mixpanel.stg_mixpanel__event_tmp ........... [RUN]
16:30:02  189 of 404 OK created sql table model int_galileo_app.patient_outreach_summary . [SELECT in 25.75s]
16:30:02  196 of 404 START sql table model int_galileo_app.preferred_providers_daily ..... [RUN]
16:30:03  190 of 404 OK created sql table model int_galileo_app.phr_allergies_daily ...... [SELECT in 23.30s]
16:30:03  197 of 404 START sql table model stg_galileo_app.delivery_patient_operating_data  [RUN]
16:30:05  191 of 404 OK created sql table model int_galileo_app.phr_issues_daily ......... [SELECT in 23.37s]
16:30:05  198 of 404 START sql table model int_gchart.gchart_care_documentation_rxadh_notes  [RUN]
16:30:07  195 of 404 OK created sql view model int_mixpanel.stg_mixpanel__event_tmp ...... [CREATE VIEW in 7.88s]
16:30:07  199 of 404 START sql table model marts_delivery_quality.quality_deal_metadata .. [RUN]
16:30:09  192 of 404 OK created sql table model int_galileo_app.phr_medications_daily .... [SELECT in 25.58s]
16:30:09  200 of 404 START sql table model int_galileo_app.psa_accounts .................. [RUN]
16:30:11  193 of 404 OK created sql table model int_galileo_app.phr_procedures_daily ..... [SELECT in 20.54s]
16:30:11  201 of 404 START sql table model int_galileo_app.case_lookup ................... [RUN]
16:30:21  194 of 404 OK created sql table model int_galileo_app.phr_vaccines_daily ....... [SELECT in 24.31s]
16:30:21  202 of 404 START sql view model int_galileo_app.case_notations_interim ......... [RUN]
16:30:23  196 of 404 OK created sql table model int_galileo_app.preferred_providers_daily  [SELECT in 20.81s]
16:30:23  203 of 404 START sql table model int_galileo_app.transactional_cases ........... [RUN]
16:30:25  197 of 404 OK created sql table model stg_galileo_app.delivery_patient_operating_data  [SELECT in 21.06s]
16:30:25  204 of 404 START sql table model stg_nc_hie.nc_hie_admission_discharge_v4 ...... [RUN]
16:30:26  199 of 404 OK created sql table model marts_delivery_quality.quality_deal_metadata  [SELECT in 19.50s]
16:30:26  205 of 404 START sql table model stg_healthix.ny_healthix_clinical_alerts_combined  [RUN]
16:30:28  200 of 404 OK created sql table model int_galileo_app.psa_accounts ............. [SELECT in 19.02s]
16:30:28  206 of 404 START sql table model int_galileo_app.case_todos .................... [RUN]
16:30:30  201 of 404 OK created sql table model int_galileo_app.case_lookup .............. [SELECT in 19.39s]
16:30:30  207 of 404 START sql table model int_servicetitan.servicetitan_med_claims_population  [RUN]
16:30:36  202 of 404 OK created sql view model int_galileo_app.case_notations_interim .... [CREATE VIEW in 15.26s]
16:30:36  208 of 404 START sql table model int_servicetitan.servicetitan_member_months ... [RUN]
16:30:45  198 of 404 OK created sql table model int_gchart.gchart_care_documentation_rxadh_notes  [SELECT in 39.83s]
16:30:45  209 of 404 START sql table model int_galileo_app.provider_shifts ............... [RUN]
16:30:47  203 of 404 OK created sql table model int_galileo_app.transactional_cases ...... [SELECT in 24.11s]
16:30:47  210 of 404 START sql table model marts_digital.postcase_feeling ................ [RUN]
16:30:59  204 of 404 OK created sql table model stg_nc_hie.nc_hie_admission_discharge_v4 . [SELECT in 34.00s]
16:30:59  211 of 404 START sql table model int_galileo_app.video_offer_type .............. [RUN]
16:31:03  207 of 404 OK created sql table model int_servicetitan.servicetitan_med_claims_population  [SELECT in 32.31s]
16:31:03  212 of 404 START sql table model int_galileo_app.subscription_periods_grouped .. [RUN]
16:31:05  205 of 404 OK created sql table model stg_healthix.ny_healthix_clinical_alerts_combined  [SELECT in 38.33s]
16:31:05  213 of 404 START sql table model int_galileo_app.subscription_events ........... [RUN]
16:31:06  208 of 404 OK created sql table model int_servicetitan.servicetitan_member_months  [SELECT in 30.16s]
16:31:06  214 of 404 START sql view model stg_uhc.uhc_claims_union ....................... [RUN]
16:31:09  206 of 404 OK created sql table model int_galileo_app.case_todos ............... [SELECT in 40.70s]
16:31:09  215 of 404 START sql table model int_uhc.uhc_adt_er_combined ................... [RUN]
16:31:11  209 of 404 OK created sql table model int_galileo_app.provider_shifts .......... [SELECT in 26.23s]
16:31:11  216 of 404 START sql table model int_uhc.uhc_adt_ip_combined ................... [RUN]
16:31:15  211 of 404 OK created sql table model int_galileo_app.video_offer_type ......... [SELECT in 16.74s]
16:31:15  217 of 404 START sql table model stg_risk_adjustment.uhc_closed_gap_members .... [RUN]
16:31:20  214 of 404 OK created sql view model stg_uhc.uhc_claims_union .................. [CREATE VIEW in 13.99s]
16:31:20  218 of 404 START sql table model stg_risk_adjustment.uhc_aca_risk .............. [RUN]
16:31:22  212 of 404 OK created sql table model int_galileo_app.subscription_periods_grouped  [SELECT in 19.42s]
16:31:22  219 of 404 START sql table model int_vcm.vcm_claims_longitudinal ............... [RUN]
16:31:27  213 of 404 OK created sql table model int_galileo_app.subscription_events ...... [SELECT in 22.12s]
16:31:27  220 of 404 START sql table model stg_villagecare.vcm_member_attribution ........ [RUN]
16:31:34  217 of 404 OK created sql table model stg_risk_adjustment.uhc_closed_gap_members  [SELECT in 18.70s]
16:31:34  221 of 404 START sql table model stg_wellcare.wellcare_census_clean ............ [RUN]
16:31:48  210 of 404 OK created sql table model marts_digital.postcase_feeling ........... [SELECT in 61.52s]
16:31:48  222 of 404 START sql table model stg_wellcare.wellcare_claims_clean ............ [RUN]
16:31:51  216 of 404 OK created sql table model int_uhc.uhc_adt_ip_combined .............. [SELECT in 39.52s]
16:31:51  223 of 404 START sql table model stg_wellcare.wellcare_rosters_clean ........... [RUN]
16:31:53  220 of 404 OK created sql table model stg_villagecare.vcm_member_attribution ... [SELECT in 25.65s]
16:31:53  224 of 404 START sql table model marts_digital.video_consultations ............. [RUN]
16:31:54  219 of 404 OK created sql table model int_vcm.vcm_claims_longitudinal .......... [SELECT in 32.03s]
16:31:54  225 of 404 START sql table model stg_bcnc.bcnc_inpatient_discharges ............ [RUN]
16:31:56  218 of 404 OK created sql table model stg_risk_adjustment.uhc_aca_risk ......... [SELECT in 35.88s]
16:31:56  226 of 404 START sql table model marts_delivery.delivery_patients .............. [RUN]
16:31:58  221 of 404 OK created sql table model stg_wellcare.wellcare_census_clean ....... [SELECT in 23.73s]
16:31:58  227 of 404 START sql table model stg_healthfirst.gaps_in_care_v1 ............... [RUN]
16:32:23  225 of 404 OK created sql table model stg_bcnc.bcnc_inpatient_discharges ....... [SELECT in 28.72s]
16:32:23  228 of 404 START sql table model stg_healthfirst.healthfirst_eligibility_v1 .... [RUN]
16:32:25  224 of 404 OK created sql table model marts_digital.video_consultations ........ [SELECT in 31.94s]
16:32:25  229 of 404 START sql table model stg_healthfirst.hf_prior_day_admissions ....... [RUN]
16:32:26  223 of 404 OK created sql table model stg_wellcare.wellcare_rosters_clean ...... [SELECT in 35.74s]
16:32:26  230 of 404 START sql table model stg_health_exchanges.nc_hie_admission_discharge  [RUN]
16:32:30  222 of 404 OK created sql table model stg_wellcare.wellcare_claims_clean ....... [SELECT in 41.76s]
16:32:30  231 of 404 START sql table model int_galileo_app.address ....................... [RUN]
16:32:32  226 of 404 OK created sql table model marts_delivery.delivery_patients ......... [SELECT in 35.63s]
16:32:32  232 of 404 START sql table model int_delivery.person_demographics .............. [RUN]
16:32:39  227 of 404 OK created sql table model stg_healthfirst.gaps_in_care_v1 .......... [SELECT in 41.41s]
16:32:39  233 of 404 START sql table model int_galileo_app.bulletins_actioned_daily ...... [RUN]
16:32:41  228 of 404 OK created sql table model stg_healthfirst.healthfirst_eligibility_v1  [SELECT in 17.85s]
16:32:41  234 of 404 START sql table model int_uhc.uhc_member_month ...................... [RUN]
16:32:43  215 of 404 OK created sql table model int_uhc.uhc_adt_er_combined .............. [SELECT in 94.25s]
16:32:43  235 of 404 START sql table model int_uhc.uhc_roster ............................ [RUN]
16:32:48  230 of 404 OK created sql table model stg_health_exchanges.nc_hie_admission_discharge  [SELECT in 21.23s]
16:32:48  236 of 404 START sql table model int_uhc.uhc_roster_details .................... [RUN]
16:32:55  232 of 404 OK created sql table model int_delivery.person_demographics ......... [SELECT in 22.78s]
16:32:55  237 of 404 START sql table model int_lookup.ndc ................................ [RUN]
16:33:03  229 of 404 OK created sql table model stg_healthfirst.hf_prior_day_admissions .. [SELECT in 38.34s]
16:33:03  238 of 404 START sql table model stg_lookup.affiliation_lookup ................. [RUN]
16:33:04  231 of 404 OK created sql table model int_galileo_app.address .................. [SELECT in 34.40s]
16:33:04  239 of 404 START sql view model stg_roster_ingestion.rosters_v2 ................ [RUN]
16:33:06  233 of 404 OK created sql table model int_galileo_app.bulletins_actioned_daily . [SELECT in 26.68s]
16:33:06  240 of 404 START sql table model int_salesforce.salesforce_native_roster ....... [RUN]
16:33:33  239 of 404 OK created sql view model stg_roster_ingestion.rosters_v2 ........... [CREATE VIEW in 28.67s]
16:33:33  241 of 404 START sql table model marts_delivery.patient_outreaches ............. [RUN]
16:33:35  238 of 404 OK created sql table model stg_lookup.affiliation_lookup ............ [SELECT in 32.33s]
16:33:35  242 of 404 START sql incremental model dbt_mixpanel.mixpanel__event ............ [RUN]
16:33:37  235 of 404 OK created sql table model int_uhc.uhc_roster ....................... [SELECT in 54.22s]
16:33:37  243 of 404 START sql table model marts_delivery.bcnc_all_gaps_in_care_prospective  [RUN]
16:33:41  237 of 404 OK created sql table model int_lookup.ndc ........................... [SELECT in 45.94s]
16:33:41  244 of 404 START sql table model stg_villagecare.hedis_gaps_v2 ................. [RUN]
16:33:45  240 of 404 OK created sql table model int_salesforce.salesforce_native_roster .. [SELECT in 38.76s]
16:33:45  245 of 404 START sql table model marts_digital.case_notations .................. [RUN]
16:33:46  236 of 404 OK created sql table model int_uhc.uhc_roster_details ............... [SELECT in 58.69s]
16:33:46  246 of 404 START sql table model int_galileo_app.case_notations_end ............ [RUN]
16:33:48  234 of 404 OK created sql table model int_uhc.uhc_member_month ................. [SELECT in 67.29s]
16:33:48  247 of 404 START sql table model int_servicetitan.servicetitan_med_claims_service  [RUN]
16:33:54  178 of 404 OK created sql table model stg_mvp.mvp_full_roster .................. [SELECT in 294.35s]
16:33:54  248 of 404 START sql table model int_galileo_app.int_review_claim .............. [RUN]
16:33:58  241 of 404 OK created sql table model marts_delivery.patient_outreaches ........ [SELECT in 25.27s]
16:33:58  249 of 404 START sql table model int_galileo_app.todo_operator_states .......... [RUN]
16:34:13  247 of 404 OK created sql table model int_servicetitan.servicetitan_med_claims_service  [SELECT in 24.93s]
16:34:13  250 of 404 START sql table model int_galileo_app.clinician_shifts_timeline ..... [RUN]
16:34:16  248 of 404 OK created sql table model int_galileo_app.int_review_claim ......... [SELECT in 21.72s]
16:34:16  251 of 404 START sql table model stg_uhc.uhc_med_claims ........................ [RUN]
16:34:18  246 of 404 OK created sql table model int_galileo_app.case_notations_end ....... [SELECT in 31.66s]
16:34:18  252 of 404 START sql table model int_galileo_app.group_sponsor_mapping ......... [RUN]
16:34:21  245 of 404 OK created sql table model marts_digital.case_notations ............. [SELECT in 36.61s]
16:34:21  253 of 404 START sql table model int_galileo_app.inflow_interim ................ [RUN]
16:34:24  243 of 404 OK created sql table model marts_delivery.bcnc_all_gaps_in_care_prospective  [SELECT in 46.20s]
16:34:24  254 of 404 START sql view model int_vcm.vcm_member_month ....................... [RUN]
16:34:26  244 of 404 OK created sql table model stg_villagecare.hedis_gaps_v2 ............ [SELECT in 45.13s]
16:34:26  255 of 404 START sql table model int_wellcare.wellcare_galileo_adt ............. [RUN]
16:34:35  250 of 404 OK created sql table model int_galileo_app.clinician_shifts_timeline  [SELECT in 21.48s]
16:34:35  256 of 404 START sql table model int_galileo_adt.gadt_bcnc_ip_dischs ........... [RUN]
16:34:37  254 of 404 OK created sql view model int_vcm.vcm_member_month .................. [CREATE VIEW in 13.46s]
16:34:37  257 of 404 START sql table model int_galileo_app.completed_video_visits ........ [RUN]
16:34:41  253 of 404 OK created sql table model int_galileo_app.inflow_interim ........... [SELECT in 20.17s]
16:34:41  258 of 404 START sql table model int_galileo_app.video_consultations_start ..... [RUN]
16:34:46  255 of 404 OK created sql table model int_wellcare.wellcare_galileo_adt ........ [SELECT in 20.02s]
16:34:46  259 of 404 START sql view model int_wellcare.wellcare_med_claims_longitudinal .. [RUN]
16:34:48  252 of 404 OK created sql table model int_galileo_app.group_sponsor_mapping .... [SELECT in 30.43s]
16:34:48  260 of 404 START sql table model stg_analytics.accrued_hcc_raf_monthly ......... [RUN]
16:34:58  256 of 404 OK created sql table model int_galileo_adt.gadt_bcnc_ip_dischs ...... [SELECT in 23.74s]
16:34:58  261 of 404 START sql table model stg_bcnc.med_claims_runout .................... [RUN]
16:35:00  257 of 404 OK created sql table model int_galileo_app.completed_video_visits ... [SELECT in 22.59s]
16:35:00  262 of 404 START sql table model stg_bcnc.med_claims_wrap ...................... [RUN]
16:35:00  259 of 404 OK created sql view model int_wellcare.wellcare_med_claims_longitudinal  [CREATE VIEW in 14.67s]
16:35:00  263 of 404 START sql table model stg_bcnc.bcnc_medication_adherence ............ [RUN]
16:35:02  258 of 404 OK created sql table model int_galileo_app.video_consultations_start  [SELECT in 20.39s]
16:35:02  264 of 404 START sql table model stg_risk_adjustment.bcnc_suspected_hcc ........ [RUN]
16:35:05  242 of 404 OK created sql incremental model dbt_mixpanel.mixpanel__event ....... [INSERT 0 769 in 89.39s]
16:35:05  265 of 404 START sql view model stg_gsheets.delivery_legacy_visits ............. [RUN]
16:35:24  260 of 404 OK created sql table model stg_analytics.accrued_hcc_raf_monthly .... [SELECT in 35.72s]
16:35:24  266 of 404 START sql table model int_galileo_adt.gadt_healthix_clinical_alerts . [RUN]
16:35:55  249 of 404 OK created sql table model int_galileo_app.todo_operator_states ..... [SELECT in 116.54s]
16:35:55  267 of 404 START sql view model stg_gsheets.gcal_data .......................... [RUN]
16:35:57  265 of 404 OK created sql view model stg_gsheets.delivery_legacy_visits ........ [CREATE VIEW in 52.43s]
16:35:57  268 of 404 START sql table model stg_analytics.stg_predictive_admissions ....... [RUN]
16:36:01  262 of 404 OK created sql table model stg_bcnc.med_claims_wrap ................. [SELECT in 61.16s]
16:36:01  269 of 404 START sql table model stg_healthfirst.hf_member_new_cohort .......... [RUN]
16:36:03  264 of 404 OK created sql table model stg_risk_adjustment.bcnc_suspected_hcc ... [SELECT in 60.82s]
16:36:03  270 of 404 START sql table model int_galileo_adt.gadt_uhc_reports .............. [RUN]
16:36:04  266 of 404 OK created sql table model int_galileo_adt.gadt_healthix_clinical_alerts  [SELECT in 39.98s]
16:36:04  271 of 404 START sql table model int_galileo_adt.gadt_nc_hie ................... [RUN]
16:36:06  267 of 404 OK created sql view model stg_gsheets.gcal_data ..................... [CREATE VIEW in 11.21s]
16:36:06  272 of 404 START sql table model int_galileo_adt.gadt_hf_prior_day_admits ...... [RUN]
16:36:21  268 of 404 OK created sql table model stg_analytics.stg_predictive_admissions .. [SELECT in 23.63s]
16:36:21  273 of 404 START sql table model int_galileo_app.active_patient_accounts ....... [RUN]
16:36:23  270 of 404 OK created sql table model int_galileo_adt.gadt_uhc_reports ......... [SELECT in 20.03s]
16:36:23  274 of 404 START sql table model int_galileo_app.address_daily ................. [RUN]
16:36:24  269 of 404 OK created sql table model stg_healthfirst.hf_member_new_cohort ..... [SELECT in 23.26s]
16:36:24  275 of 404 START sql table model stg_galileo_app.raw_employer_rosters .......... [RUN]
16:36:26  271 of 404 OK created sql table model int_galileo_adt.gadt_nc_hie .............. [SELECT in 21.80s]
16:36:26  276 of 404 START sql table model int_vcm.vcm_roster_details .................... [RUN]
16:36:27  272 of 404 OK created sql table model int_galileo_adt.gadt_hf_prior_day_admits . [SELECT in 21.16s]
16:36:27  277 of 404 START sql table model int_wellcare.wellcare_roster_details .......... [RUN]
16:37:21  274 of 404 OK created sql table model int_galileo_app.address_daily ............ [SELECT in 58.04s]
16:37:21  278 of 404 START sql table model marts_digital.galileo_initiated_rx ............ [RUN]
16:37:24  273 of 404 OK created sql table model int_galileo_app.active_patient_accounts .. [SELECT in 63.32s]
16:37:24  279 of 404 START sql table model marts_digital.pharmacy_refill_requests ........ [RUN]
16:37:26  263 of 404 OK created sql table model stg_bcnc.bcnc_medication_adherence ....... [SELECT in 145.67s]
16:37:26  280 of 404 START sql table model int_mvp.mvp_roster_details .................... [RUN]
16:37:31  277 of 404 OK created sql table model int_wellcare.wellcare_roster_details ..... [SELECT in 63.69s]
16:37:31  281 of 404 START sql table model marts_delivery.bcnc_current_gaps_in_care_prospective  [RUN]
16:37:38  276 of 404 OK created sql table model int_vcm.vcm_roster_details ............... [SELECT in 72.43s]
16:37:38  282 of 404 START sql table model marts_quality.all_gaps_in_care_prospective .... [RUN]
16:37:46  278 of 404 OK created sql table model marts_digital.galileo_initiated_rx ....... [SELECT in 25.38s]
16:37:46  283 of 404 START sql table model marts_digital.inflow .......................... [RUN]
16:37:51  279 of 404 OK created sql table model marts_digital.pharmacy_refill_requests ... [SELECT in 26.21s]
16:37:51  284 of 404 START sql table model marts_risk_adjustment.latest_accrued_raf ...... [RUN]
16:38:21  281 of 404 OK created sql table model marts_delivery.bcnc_current_gaps_in_care_prospective  [SELECT in 49.56s]
16:38:21  285 of 404 START sql table model int_galileo_app.cherrypicked_todos ............ [RUN]
16:38:27  282 of 404 OK created sql table model marts_quality.all_gaps_in_care_prospective  [SELECT in 48.85s]
16:38:27  286 of 404 START sql table model int_galileo_app.galileo_completed_todo ........ [RUN]
16:38:29  280 of 404 OK created sql table model int_mvp.mvp_roster_details ............... [SELECT in 62.84s]
16:38:29  287 of 404 START sql table model int_galileo_app.post_review_case_timeline ..... [RUN]
16:39:39  283 of 404 OK created sql table model marts_digital.inflow ..................... [SELECT in 113.20s]
16:39:39  288 of 404 START sql table model int_galileo_app.todos_completed_by_patient .... [RUN]
16:39:41  284 of 404 OK created sql table model marts_risk_adjustment.latest_accrued_raf . [SELECT in 110.28s]
16:39:41  289 of 404 START sql table model int_risk_adjustment.ma_suspect_hcc ............ [RUN]
16:40:02  275 of 404 OK created sql table model stg_galileo_app.raw_employer_rosters ..... [SELECT in 218.29s]
16:40:02  290 of 404 START sql view model int_gsheets.delivery_gcal_visits ............... [RUN]
16:40:07  286 of 404 OK created sql table model int_galileo_app.galileo_completed_todo ... [SELECT in 99.77s]
16:40:07  291 of 404 START sql table model marts_delivery.person_delivery ................ [RUN]
16:40:10  287 of 404 OK created sql table model int_galileo_app.post_review_case_timeline  [SELECT in 101.01s]
16:40:10  292 of 404 START sql table model stg_healthfirst.hf_member_attribution ......... [RUN]
16:40:12  288 of 404 OK created sql table model int_galileo_app.todos_completed_by_patient  [SELECT in 32.32s]
16:40:12  293 of 404 START sql table model int_galileo_adt.unified_galileo_adt ........... [RUN]
16:40:13  290 of 404 OK created sql view model int_gsheets.delivery_gcal_visits .......... [CREATE VIEW in 10.86s]
16:40:13  294 of 404 START sql table model int_braze.braze_subscription_status ........... [RUN]
16:40:17  289 of 404 OK created sql table model int_risk_adjustment.ma_suspect_hcc ....... [SELECT in 35.77s]
16:40:17  295 of 404 START sql table model int_galileo_app.date_lookup ................... [RUN]
16:40:22  291 of 404 OK created sql table model marts_delivery.person_delivery ........... [SELECT in 15.36s]
16:40:22  296 of 404 START sql table model int_mixpanel.mixpanel_device_account_match .... [RUN]
16:40:27  292 of 404 OK created sql table model stg_healthfirst.hf_member_attribution .... [SELECT in 16.68s]
16:40:27  297 of 404 START sql table model int_galileo_app.todo_facts .................... [RUN]
16:40:53  294 of 404 OK created sql table model int_braze.braze_subscription_status ...... [SELECT in 39.89s]
16:40:53  298 of 404 START sql table model int_bcnc.csar_processed ....................... [RUN]
16:41:43  261 of 404 OK created sql table model stg_bcnc.med_claims_runout ............... [SELECT in 404.53s]
16:41:43  299 of 404 START sql table model marts_quality.current_gaps_in_care_prospective  [RUN]
16:41:45  293 of 404 OK created sql table model int_galileo_adt.unified_galileo_adt ...... [SELECT in 93.42s]
16:41:45  300 of 404 START sql table model marts_quality.latest_open_gaps_from_payer ..... [RUN]
16:41:51  296 of 404 OK created sql table model int_mixpanel.mixpanel_device_account_match  [SELECT in 88.77s]
16:41:51  301 of 404 START sql table model int_partners.rosters .......................... [RUN]
16:42:02  285 of 404 OK created sql table model int_galileo_app.cherrypicked_todos ....... [SELECT in 221.68s]
16:42:02  302 of 404 START sql table model int_galileo_app.subscriber_upgrade_daily ...... [RUN]
16:42:08  298 of 404 OK created sql table model int_bcnc.csar_processed .................. [SELECT in 74.55s]
16:42:08  303 of 404 START sql table model int_galileo_app.employer_rosters .............. [RUN]
16:42:13  297 of 404 OK created sql table model int_galileo_app.todo_facts ............... [SELECT in 106.55s]
16:42:13  304 of 404 START sql table model int_galileo_app.progress_todo ................. [RUN]
16:42:15  299 of 404 OK created sql table model marts_quality.current_gaps_in_care_prospective  [SELECT in 32.41s]
16:42:15  305 of 404 START sql table model int_galileo_app.todos_daily_completed_by_patient  [RUN]
16:42:17  300 of 404 OK created sql table model marts_quality.latest_open_gaps_from_payer  [SELECT in 31.57s]
16:42:17  306 of 404 START sql table model marts_encounters.delivery_gcal ................ [RUN]
16:42:25  302 of 404 OK created sql table model int_galileo_app.subscriber_upgrade_daily . [SELECT in 22.50s]
16:42:25  307 of 404 START sql table model marts_delivery_quality.gap_status_history ..... [RUN]
16:42:39  301 of 404 OK created sql table model int_partners.rosters ..................... [SELECT in 48.25s]
16:42:39  308 of 404 START sql view model int_hf.hf_member_month ......................... [RUN]
16:42:43  305 of 404 OK created sql table model int_galileo_app.todos_daily_completed_by_patient  [SELECT in 27.26s]
16:42:43  309 of 404 START sql table model int_bcnc.med_claims_monthly_population ........ [RUN]
16:42:46  304 of 404 OK created sql table model int_galileo_app.progress_todo ............ [SELECT in 32.40s]
16:42:46  310 of 404 START sql table model marts_health_exchanges.person_day_adt ......... [RUN]
16:42:53  306 of 404 OK created sql table model marts_encounters.delivery_gcal ........... [SELECT in 36.20s]
16:42:53  311 of 404 START sql incremental model marts_digital.mixpanel_event ............ [RUN]
16:42:54  308 of 404 OK created sql view model int_hf.hf_member_month .................... [CREATE VIEW in 14.08s]
16:42:54  312 of 404 START sql table model int_bcnc.csar_most_recent ..................... [RUN]
16:43:10  295 of 404 OK created sql table model int_galileo_app.date_lookup .............. [SELECT in 173.14s]
16:43:10  313 of 404 START sql table model int_delivery.denominator ...................... [RUN]
16:43:11  310 of 404 OK created sql table model marts_health_exchanges.person_day_adt .... [SELECT in 25.67s]
16:43:11  314 of 404 START sql table model marts_encounters.person_gcal .................. [RUN]
16:43:14  303 of 404 OK created sql table model int_galileo_app.employer_rosters ......... [SELECT in 65.93s]
16:43:14  315 of 404 START sql table model int_galileo_app.subscription_facts ............ [RUN]
16:43:19  312 of 404 OK created sql table model int_bcnc.csar_most_recent ................ [SELECT in 25.44s]
16:43:19  316 of 404 START sql table model marts_health_exchanges.person_adt ............. [RUN]
16:43:27  314 of 404 OK created sql table model marts_encounters.person_gcal ............. [SELECT in 16.22s]
16:43:27  317 of 404 START sql table model int_galileo_app.employer_roster_file_spans .... [RUN]
16:43:45  316 of 404 OK created sql table model marts_health_exchanges.person_adt ........ [SELECT in 25.68s]
16:43:45  318 of 404 START sql table model marts_delivery_quality.medication_adherence_and_care_docs  [RUN]
16:43:48  313 of 404 OK created sql table model int_delivery.denominator ................. [SELECT in 37.85s]
16:44:15  307 of 404 OK created sql table model marts_delivery_quality.gap_status_history  [SELECT in 109.90s]
16:44:17  317 of 404 OK created sql table model int_galileo_app.employer_roster_file_spans  [SELECT in 49.32s]
16:44:17  319 of 404 START sql table model int_galileo_app.employer_roster_details ....... [RUN]
16:44:20  309 of 404 OK created sql table model int_bcnc.med_claims_monthly_population ... [SELECT in 97.58s]
16:44:20  320 of 404 START sql table model int_bcnc.med_claims_service_longitudinal ...... [RUN]
16:44:22  318 of 404 OK created sql table model marts_delivery_quality.medication_adherence_and_care_docs  [SELECT in 36.90s]
16:44:26  311 of 404 OK created sql incremental model marts_digital.mixpanel_event ....... [INSERT 0 1276412 in 93.69s]
16:44:26  321 of 404 START sql incremental model int_mixpanel.mixpanel_first_app_download  [RUN]
16:44:26  322 of 404 START sql incremental model int_mixpanel.mixpanel_first_login ....... [RUN]
16:44:39  319 of 404 OK created sql table model int_galileo_app.employer_roster_details .. [SELECT in 21.85s]
16:44:47  320 of 404 OK created sql table model int_bcnc.med_claims_service_longitudinal . [SELECT in 27.14s]
16:44:47  323 of 404 START sql table model int_bcnc.bcnc_roster_details .................. [RUN]
16:44:47  324 of 404 START sql table model marts_delivery.delivery_member_months ......... [RUN]
16:44:52  324 of 404 ERROR creating sql table model marts_delivery.delivery_member_months  [ERROR in 4.70s]
16:44:52  325 of 404 SKIP relation marts_delivery.patients_and_operating_data ............ [SKIP]
16:44:52  326 of 404 SKIP relation int_hf.hf_roster_details .............................. [SKIP]
16:44:52  327 of 404 SKIP relation stg_encounters.patient_lookup ......................... [SKIP]
16:44:52  328 of 404 SKIP relation stg_encounters.athena_encounters ...................... [SKIP]
16:44:52  329 of 404 SKIP relation stg_encounters.athena_lab_history ..................... [SKIP]
16:44:52  330 of 404 SKIP relation stg_encounters.athena_vitals .......................... [SKIP]
16:45:20  322 of 404 OK created sql incremental model int_mixpanel.mixpanel_first_login .. [INSERT 0 0 in 53.63s]
16:45:20  315 of 404 OK created sql table model int_galileo_app.subscription_facts ....... [SELECT in 126.33s]
16:45:20  331 of 404 START sql table model int_galileo_app.tiers_daily_interim ........... [RUN]
16:45:23  321 of 404 OK created sql incremental model int_mixpanel.mixpanel_first_app_download  [INSERT 0 0 in 57.04s]
16:45:30  323 of 404 OK created sql table model int_bcnc.bcnc_roster_details ............. [SELECT in 43.21s]
16:45:30  332 of 404 SKIP relation int_partners.other_delivery_roster_details ............ [SKIP]
16:45:30  333 of 404 SKIP relation int_partners.union_roster_details ..................... [SKIP]
16:45:30  334 of 404 SKIP relation marts_risk_adjustment.mra_person ...................... [SKIP]
16:45:30  335 of 404 SKIP relation int_partners.roster_account_matches ................... [SKIP]
16:45:30  336 of 404 SKIP relation int_partners.union_roster_spans ....................... [SKIP]
16:45:30  337 of 404 SKIP relation int_braze.braze_upload_employer_roster ................ [SKIP]
16:45:30  338 of 404 SKIP relation int_partners.affiliation_spans ........................ [SKIP]
16:45:30  339 of 404 SKIP relation marts_ext_copperhill.ext_account_contact_relationship . [SKIP]
16:45:30  340 of 404 SKIP relation int_galileo_app.patient_accounts ...................... [SKIP]
16:45:30  341 of 404 SKIP relation marts_internal_mpi.proto_master_patient_index ......... [SKIP]
16:45:30  342 of 404 SKIP relation marts_internal_mpi.delivery_patient_duplicates ........ [SKIP]
16:45:30  343 of 404 SKIP relation int_mixpanel.mixpanel_first_session ................... [SKIP]
16:45:30  344 of 404 SKIP relation marts_ext_copperhill.ext_master_patient_index ......... [SKIP]
16:45:30  345 of 404 SKIP relation marts_digital.mixpanel_first_event .................... [SKIP]
16:45:30  346 of 404 SKIP relation int_elation.elation_encounters ........................ [SKIP]
16:45:30  347 of 404 SKIP relation int_delivery.hedis_athena_lab_based ................... [SKIP]
16:45:30  348 of 404 SKIP relation marts_encounters.unified_enc_service .................. [SKIP]
16:45:30  349 of 404 SKIP relation int_delivery.hedis_athena_cpt_based ................... [SKIP]
16:45:30  350 of 404 SKIP relation int_delivery.hedis_athena_vitals_cpt_based ............ [SKIP]
16:46:22  251 of 404 OK created sql table model stg_uhc.uhc_med_claims ................... [SELECT in 726.33s]
16:46:22  351 of 404 START sql view model int_uhc.uhc_med_claims_monthly_population ...... [RUN]
16:46:30  351 of 404 OK created sql view model int_uhc.uhc_med_claims_monthly_population . [CREATE VIEW in 8.29s]
16:46:30  352 of 404 START sql table model int_uhc.uhc_med_claims_service_longitudinal ... [RUN]
16:46:53  352 of 404 OK created sql table model int_uhc.uhc_med_claims_service_longitudinal  [SELECT in 22.62s]
16:46:53  353 of 404 START sql table model marts_medical_claims.unified_med_claims_service  [RUN]
16:48:23  331 of 404 OK created sql table model int_galileo_app.tiers_daily_interim ...... [SELECT in 182.95s]
16:48:23  354 of 404 START sql table model int_galileo_app.churn_curve_interim ........... [RUN]
16:48:23  355 of 404 START sql table model marts_digital.quiz_submissions ................ [RUN]
16:48:23  356 of 404 START sql table model int_galileo_app.transactional_dates ........... [RUN]
16:48:28  353 of 404 OK created sql table model marts_medical_claims.unified_med_claims_service  [SELECT in 94.78s]
16:48:28  357 of 404 START sql table model int_delivery.hedis_cbp_hg_closed .............. [RUN]
16:48:46  356 of 404 OK created sql table model int_galileo_app.transactional_dates ...... [SELECT in 22.82s]
16:48:54  355 of 404 OK created sql table model marts_digital.quiz_submissions ........... [SELECT in 31.17s]
16:48:54  358 of 404 START sql table model int_galileo_app.quiz_submissions_daily ........ [RUN]
16:49:13  358 of 404 OK created sql table model int_galileo_app.quiz_submissions_daily ... [SELECT in 18.44s]
16:49:14  354 of 404 OK created sql table model int_galileo_app.churn_curve_interim ...... [SELECT in 51.16s]
16:49:14  359 of 404 START sql table model int_galileo_app.cases_interim ................. [RUN]
16:49:14  360 of 404 START sql table model int_galileo_app.tiers_daily ................... [RUN]
16:49:45  359 of 404 OK created sql table model int_galileo_app.cases_interim ............ [SELECT in 30.14s]
16:49:45  361 of 404 START sql table model marts_digital.churn_curve ..................... [RUN]
16:49:45  362 of 404 START sql table model int_galileo_app.galileo_initiated_cases ....... [RUN]
16:49:57  357 of 404 OK created sql table model int_delivery.hedis_cbp_hg_closed ......... [SELECT in 88.74s]
16:49:57  363 of 404 SKIP relation marts_delivery_quality.ehr_gap_report ................. [SKIP]
16:49:57  364 of 404 SKIP relation int_delivery.hedis_gaps ............................... [SKIP]
16:49:57  365 of 404 SKIP relation marts_delivery_quality.realtime_gap_status ............ [SKIP]
16:49:57  366 of 404 SKIP relation marts_quality.care_gaps ............................... [SKIP]
16:49:57  367 of 404 SKIP relation marts_delivery_quality.hf_encounter_submission ........ [SKIP]
16:49:57  368 of 404 SKIP relation marts_delivery_quality.hf_lab_submission .............. [SKIP]
16:49:57  369 of 404 SKIP relation marts_delivery_quality.person_quality ................. [SKIP]
16:49:57  370 of 404 SKIP relation marts_delivery_quality.realtime_gap_adherence_care .... [SKIP]
16:49:57  371 of 404 SKIP relation marts_delivery_quality.vcm_encounter_submission ....... [SKIP]
16:49:57  372 of 404 SKIP relation marts_quality.care_gaps_current ....................... [SKIP]
16:50:11  362 of 404 OK created sql table model int_galileo_app.galileo_initiated_cases .. [SELECT in 26.66s]
16:50:13  361 of 404 OK created sql table model marts_digital.churn_curve ................ [SELECT in 28.43s]
16:52:15  360 of 404 OK created sql table model int_galileo_app.tiers_daily .............. [SELECT in 180.69s]
16:52:15  373 of 404 START sql table model int_galileo_app.messages_interim .............. [RUN]
16:55:11  373 of 404 OK created sql table model int_galileo_app.messages_interim ......... [SELECT in 176.17s]
16:55:11  374 of 404 START sql table model int_galileo_app.quest_messages ................ [RUN]
16:55:11  375 of 404 START sql table model int_galileo_app.video_complete_clinician ...... [RUN]
16:55:26  375 of 404 OK created sql table model int_galileo_app.video_complete_clinician . [SELECT in 15.07s]
16:55:29  374 of 404 OK created sql table model int_galileo_app.quest_messages ........... [SELECT in 17.67s]
16:55:29  376 of 404 START sql table model int_galileo_app.messages_additional ........... [RUN]
16:56:29  376 of 404 OK created sql table model int_galileo_app.messages_additional ...... [SELECT in 60.06s]
16:56:29  377 of 404 START sql table model int_galileo_app.messages_daily ................ [RUN]
16:56:29  378 of 404 START sql table model int_galileo_app.staging_messages .............. [RUN]
16:56:42  377 of 404 OK created sql table model int_galileo_app.messages_daily ........... [SELECT in 12.72s]
16:56:58  378 of 404 OK created sql table model int_galileo_app.staging_messages ......... [SELECT in 29.21s]
16:56:58  379 of 404 START sql table model int_galileo_app.completed_no_response_messages  [RUN]
16:56:58  380 of 404 START sql table model int_galileo_app.messages_by_person ............ [RUN]
16:57:11  380 of 404 OK created sql table model int_galileo_app.messages_by_person ....... [SELECT in 12.81s]
16:57:18  379 of 404 OK created sql table model int_galileo_app.completed_no_response_messages  [SELECT in 20.27s]
16:57:18  381 of 404 START sql table model marts_digital.case_messages ................... [RUN]
16:58:22  381 of 404 OK created sql table model marts_digital.case_messages .............. [SELECT in 63.47s]
16:58:22  382 of 404 START sql table model int_galileo_app.clinicians_per_case ........... [RUN]
16:58:22  383 of 404 START sql table model marts_digital.episodes_case_mesg_daily ........ [RUN]
16:58:22  384 of 404 START sql table model int_galileo_app.post_rct_clinician_mesg ....... [RUN]
16:58:22  385 of 404 START sql table model int_galileo_app.pre_review_case_timeline ...... [RUN]
16:58:37  384 of 404 OK created sql table model int_galileo_app.post_rct_clinician_mesg .. [SELECT in 14.72s]
16:58:38  382 of 404 OK created sql table model int_galileo_app.clinicians_per_case ...... [SELECT in 15.97s]
16:58:50  385 of 404 OK created sql table model int_galileo_app.pre_review_case_timeline . [SELECT in 28.11s]
16:58:50  386 of 404 START sql table model int_galileo_app.pre_rct_other_todos ........... [RUN]
16:58:51  383 of 404 OK created sql table model marts_digital.episodes_case_mesg_daily ... [SELECT in 29.37s]
16:58:51  387 of 404 START sql table model int_galileo_app.interim_simple_episodes ....... [RUN]
16:59:01  386 of 404 OK created sql table model int_galileo_app.pre_rct_other_todos ...... [SELECT in 10.70s]
16:59:01  388 of 404 START sql table model int_galileo_app.pre_rct_union_states .......... [RUN]
16:59:04  387 of 404 OK created sql table model int_galileo_app.interim_simple_episodes .. [SELECT in 12.81s]
16:59:04  389 of 404 START sql table model marts_digital.marts_simple_episodes ........... [RUN]
16:59:20  389 of 404 OK created sql table model marts_digital.marts_simple_episodes ...... [SELECT in 15.70s]
17:00:05  388 of 404 OK created sql table model int_galileo_app.pre_rct_union_states ..... [SELECT in 64.27s]
17:00:05  390 of 404 START sql table model int_galileo_app.pre_rct_clinician_timeline .... [RUN]
17:00:16  390 of 404 OK created sql table model int_galileo_app.pre_rct_clinician_timeline  [SELECT in 10.34s]
17:00:16  391 of 404 SKIP relation marts_digital.clinician_timeline ...................... [SKIP]
17:00:16  392 of 404 SKIP relation int_galileo_app.clinician_time_by_case ................ [SKIP]
17:00:16  393 of 404 SKIP relation marts_digital.case_mesg_daily ......................... [SKIP]
17:00:16  394 of 404 SKIP relation marts_digital.cases ................................... [SKIP]
17:00:16  395 of 404 SKIP relation int_galileo_app.episode_interim ....................... [SKIP]
17:00:16  396 of 404 SKIP relation int_galileo_app.top_cases_clinician_time_person ....... [SKIP]
17:00:16  397 of 404 SKIP relation int_galileo_app.case_type_daily ....................... [SKIP]
17:00:16  398 of 404 SKIP relation int_galileo_app.episode_by_case ....................... [SKIP]
17:00:16  399 of 404 SKIP relation marts_digital.person_day .............................. [SKIP]
17:00:16  400 of 404 SKIP relation int_galileo_app.top_cases_episodes_person ............. [SKIP]
17:00:16  401 of 404 SKIP relation marts_digital.person .................................. [SKIP]
17:00:16  402 of 404 SKIP relation int_risk_adjustment.aca_payor_risk_score .............. [SKIP]
17:00:16  403 of 404 SKIP relation int_risk_adjustment.aca_payor_suspect_hcc ............. [SKIP]
17:00:16  404 of 404 SKIP relation marts_risk_adjustment.aca_suspect_master .............. [SKIP]
17:00:18
17:00:18  Running 16 on-run-end hooks
17:00:18  1 of 16 START hook: galileo.on-run-end.0 ....................................... [RUN]
17:00:19  1 of 16 OK hook: galileo.on-run-end.0 .

"""
# CW_lines = CWLogs.readline()
dbt_logs_start = True
# print(CW_lines)
for line in multiline_logs.splitlines():
    CW_lines = line
    if re.search('Running with dbt',CW_lines):
        dbt_logs_start=True
    elif re.search('on-run-end hooks',CW_lines):
        dbt_logs_start=False
    if dbt_logs_start:
        model_name_re = re.search('[a-z\_]+\.{1}[a-z\_\d]+',CW_lines)
        if model_name_re:
            if not (re.search(except_regex_string,line)):
                model_name = model_name_re.group()
                # print(line)
                models_to_rerun.append(model_name)

# %%
models_to_rerun_shortnames = []
models_failed=0
for x in models_to_rerun:
    models_failed+=1
    shortname = re.search('\.(.*)',x).group(1)
    # print(shortname)
    models_to_rerun_shortnames.append(shortname)

model_names_string = ' '.join(models_to_rerun_shortnames)
# print(model_names_string)

shell_command_to_rerun = prod_run_var_string + model_names_string
print(shell_command_to_rerun)
# Out:
# ENVIRONMENT=production AWS_PROFILE=production dbt run -m delivery_member_months patients_and_operating_data hf_roster_details patient_lookup athena_encounters athena_lab_history athena_vitals other_delivery_roster_details union_roster_details mra_person roster_account_matches union_roster_spans braze_upload_employer_roster affiliation_spans ext_account_contact_relationship patient_accounts proto_master_patient_index delivery_patient_duplicates mixpanel_first_session ext_master_patient_index mixpanel_first_event elation_encounters hedis_athena_lab_based unified_enc_service hedis_athena_cpt_based hedis_athena_vitals_cpt_based ehr_gap_report hedis_gaps realtime_gap_status care_gaps hf_encounter_submission hf_lab_submission person_quality realtime_gap_adherence_care vcm_encounter_submission care_gaps_current clinician_timeline clinician_time_by_case case_mesg_daily cases episode_interim top_cases_clinician_time_person case_type_daily episode_by_case person_day top_cases_episodes_person p
# ...

# %%
# models_failed=0
print(models_failed)
print(len(models_to_rerun_shortnames))
for model in models_to_rerun_shortnames:
    print(model)
# Out:
# 100
# 100
# delivery_member_months
# patients_and_operating_data
# hf_roster_details
# patient_lookup
# athena_encounters
# athena_lab_history
# athena_vitals
# other_delivery_roster_details
# union_roster_details
# mra_person
# roster_account_matches
# union_roster_spans
# braze_upload_employer_roster
# affiliation_spans
# ext_account_contact_relationship
# patient_accounts
# proto_master_patient_index
# delivery_patient_duplicates
# mixpanel_first_session
# ext_master_patient_index
# mixpanel_first_event
# elation_encounters
# hedis_athena_lab_based
# unified_enc_service
# hedis_athena_cpt_based
# hedis_athena_vitals_cpt_based
# ehr_gap_report
# hedis_gaps
# realtime_gap_status
# care_gaps
# hf_encounter_submission
# hf_lab_submission
# person_quality
# realtime_gap_adherence_care
# vcm_encounter_submission
# care_gaps_current
# clinician_timeline
# clinician_time_by_case
# case_mesg_daily
# cases
# episode_interim
# top_cases_clinician_time_person
# case_type_daily
# ...

# %%
print('models to rerun: ' + str(models_failed))
multiliner = """"""
if len(multiliner):
    print('mine now')
    print(len(multiliner))
# Out:
# models to rerun: 50
